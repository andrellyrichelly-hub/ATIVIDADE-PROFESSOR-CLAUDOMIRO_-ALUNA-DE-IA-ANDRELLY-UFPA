# %% [markdown]
# <a href="https://colab.research.google.com/github/andrellyrichelly-hub/ATIVIDADE-PROFESSOR-CLAUDOMIRO_-ALUNA-DE-IA-ANDRELLY-UFPA/blob/main/SLIDE_77_ATIVI_2_3_ANDRELLY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import HTML, display

# Atividade 2.3 - Slide 77 - Simulador ROM 8×4 Aluna: Andrelly Richelly
display(HTML("""
<h3>Atividade 2.3 - Slide 77</h3>
<p><b>Simulador de Memória ROM 8×4</b></p>

<p><b>1. Especificações do Projeto:</b></p>
<ul>
  <li><b>Tamanho:</b> 8 células → Precisa de 3 bits de endereço: A2, A1, A0. Porque 2³ = 8</li>
  <li><b>Largura da palavra:</b> 4 bits por célula → 4 saídas: D3, D2, D1, D0</li>
  <li><b>Total de bits:</b> 8 × 4 = 32 bits = 4 bytes</li>
  <li><b>Tipo:</b> ROM = Read-Only Memory. Não-volátil. O conteúdo é gravado uma vez e só pode ser lido.</li>
</ul>

<p><b>2. Tabela de Conteúdo da ROM - Gravada na Fabricação:</b></p>
<table style="border-collapse: collapse; width: 70%; margin: 20px 0;">
  <tr style="background-color: #FF6F00; color: white;">
    <th style="border: 1px solid #ddd; padding: 12px; text-align: center;">Endereço A2A1A0</th>
    <th style="border: 1px solid #ddd; padding: 12px; text-align: center;">Decimal</th>
    <th style="border: 1px solid #ddd; padding: 12px; text-align: center;">Conteúdo D3D2D1D0</th>
    <th style="border: 1px solid #ddd; padding: 12px; text-align: center;">Hexadecimal</th>
  </tr>
  <tr>
    <td style="border: 1px solid #ddd; padding: 8px; text-align: center;"><b>000</b></td>
    <td style="border: 1px solid #ddd; padding: 8px; text-align: center;">0</td>
    <td style="border: 1px solid #ddd; padding: 8px; text-align: center;">1010</td>
    <td style="border: 1px solid #ddd; padding: 8px; text-align: center;"><b>A</b></td>
  </tr>
  <tr style="background-color: #f2f2f2;">
    <td style="border: 1px solid #ddd; padding: 8px; text-align: center;"><b>001</b></td>
    <td style="border: 1px solid #ddd; padding: 8px; text-align: center;">1</td>
    <td style="border: 1px solid #ddd; padding: 8px; text-align: center;">0011</td>
    <td style="border: 1px solid #ddd; padding: 8px; text-align: center;"><b>3</b></td>
  </tr>
  <tr>
    <td style="border: 1px solid #ddd; padding: 8px; text-align: center;"><b>010</b></td>
    <td style="border: 1px solid #ddd; padding: 8px; text-align: center;">2</td>
    <td style="border: 1px solid #ddd; padding: 8px; text-align: center;">1111</td>
    <td style="border: 1px solid #ddd; padding: 8px; text-align: center;"><b>F</b></td>
  </tr>
  <tr style="background-color: #f2f2f2;">
    <td style="border: 1px solid #ddd; padding: 8px; text-align: center;"><b>011</b></td>
    <td style="border: 1px solid #ddd; padding: 8px; text-align: center;">3</td>
    <td style="border: 1px solid #ddd; padding: 8px; text-align: center;">0000</td>
    <td style="border: 1px solid #ddd; padding: 8px; text-align: center;"><b>0</b></td>
  </tr>
  <tr>
    <td style="border: 1px solid #ddd; padding: 8px; text-align: center;"><b>100</b></td>
    <td style="border: 1px solid #ddd; padding: 8px; text-align: center;">4</td>
    <td style="border: 1px solid #ddd; padding: 8px; text-align: center;">1100</td>
    <td style="border: 1px solid #ddd; padding: 8px; text-align: center;"><b>C</b></td>
  </tr>
  <tr style="background-color: #f2f2f2;">
    <td style="border: 1px solid #ddd; padding: 8px; text-align: center;"><b>101</b></td>
    <td style="border: 1px solid #ddd; padding: 8px; text-align: center;">5</td>
    <td style="border: 1px solid #ddd; padding: 8px; text-align: center;">0101</td>
    <td style="border: 1px solid #ddd; padding: 8px; text-align: center;"><b>5</b></td>
  </tr>
  <tr>
    <td style="border: 1px solid #ddd; padding: 8px; text-align: center;"><b>110</b></td>
    <td style="border: 1px solid #ddd; padding: 8px; text-align: center;">6</td>
    <td style="border: 1px solid #ddd; padding: 8px; text-align: center;">1001</td>
    <td style="border: 1px solid #ddd; padding: 8px; text-align: center;"><b>9</b></td>
  </tr>
  <tr style="background-color: #f2f2f2;">
    <td style="border: 1px solid #ddd; padding: 8px; text-align: center;"><b>111</b></td>
    <td style="border: 1px solid #ddd; padding: 8px; text-align: center;">7</td>
    <td style="border: 1px solid #ddd; padding: 8px; text-align: center;">0110</td>
    <td style="border: 1px solid #ddd; padding: 8px; text-align: center;"><b>6</b></td>
  </tr>
</table>

<p><b>3. Como Simular uma Leitura na ROM:</b></p>
<pre style="background-color: #263238; color: #ECEFF1; padding: 15px; border-radius: 5px; font-family: monospace;">
# SIMULADOR ROM 8×4
rom = {
  '000': '1010', # 0 → A
  '001': '0011', # 1 → 3
  '010': '1111', # 2 → F
  '011': '0000', # 3 → 0
  '100': '1100', # 4 → C
  '101': '0101', # 5 → 5
  '110': '1001', # 6 → 9
  '111': '0110' # 7 → 6
}

# Exemplo: CPU pede o endereço 101
endereco = '101'
dado = rom[endereco]
print(f"Endereço: {endereco} → Saída D3D2D1D0: {dado} → Hex: {int(dado,2):X}")
# Saída: Endereço: 101 → Saída D3D2D1D0: 0101 → Hex: 5
</pre>
"""))

# Código executável pra testar
rom = {
  '000': '1010', '001': '0011', '010': '1111', '011': '0000',
  '100': '1100', '101': '0101', '110': '1001', '111': '0110'
}

print("\n=== TESTE DO SIMULADOR ===")
for addr in rom:
    dado_bin = rom[addr]
    dado_hex = hex(int(dado_bin, 2)).upper().replace('0X','')
    print(f"Se A2A1A0 = {addr} → ROM devolve {dado_bin} = {dado_hex} em Hex")
# Out:
# <h3>Atividade 2.3 - Slide 77</h3>
# <p><b>Simulador de Memória ROM 8×4</b></p>
#
# <p><b>1. Especificações do Projeto:</b></p>
# <ul>
#   <li><b>Tamanho:</b> 8 células → Precisa de 3 bits de endereço: A2, A1, A0. Porque 2³ = 8</li>
#   <li><b>Largura da palavra:</b> 4 bits por célula → 4 saídas: D3, D2, D1, D0</li>
#   <li><b>Total de bits:</b> 8 × 4 = 32 bits = 4 bytes</li>
#   <li><b>Tipo:</b> ROM = Read-Only Memory. Não-volátil. O conteúdo é gravado uma vez e só pode ser lido.</li>
# </ul>
#
# <p><b>2. Tabela de Conteúdo da ROM - Gravada na Fabricação:</b></p>
# <table style="border-collapse: collapse; width: 70%; margin: 20px 0;">
#   <tr style="background-color: #FF6F00; color: white;">
#     <th style="border: 1px solid #ddd; padding: 12px; text-align: center;">Endereço A2A1A0</th>
#     <th style="border: 1px solid #ddd; padding: 12px; text-align: center;">Decimal</th>
#     <th style="border: 1px solid #ddd; padding: 12px; text-align: center;">Conteúdo D3D2D1D0</th>
# ...
